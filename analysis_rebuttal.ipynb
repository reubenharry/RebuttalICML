# %% [markdown]
# # Fermionic observable: Fermion number

# %%
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Occuptation number $n_{occ}$ averaged over momenta

# %%
from plots_simple import make_plots

make_plots(results_full64, "fermi_occ", 40, 64, ess_log_scale=False)
make_plots(results_full400, "fermi_occ", 400, 16, ess_log_scale=False)

# %% [markdown]
# ## Superfluid density
#
# ![superfluid](./superfluid.png)

# %% [markdown]
# ## Effect of acceptance rate on HMC efficiency, and integrator on efficiency
#
# ![](leapfrog.png)
